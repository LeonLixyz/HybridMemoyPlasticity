# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import random_split
import numpy as np
import matplotlib.pyplot as plt

# %%
def generate_seq(batch_size, vec_len, R, T):
    batch_input = []
    batch_target = []
    
    for batch in range (batch_size):
        input = []
        target = []
        for i in range(R):
            input.append(torch.bernoulli(torch.empty(vec_len).uniform_(0, 1)))
            target.append(torch.zeros(1))
        
        for i in range(R, 2*R):
            if np.random.rand() > 0.5:
                input.append(input[i-R])
                target.append(torch.ones(1))
            else:
                input.append(torch.bernoulli(torch.empty(vec_len).uniform_(0, 1)))
                target.append(torch.zeros(1))

        for i in range(2*R,T):
            if np.random.rand() > 0.5 and (not torch.equal(input[i-R],input[i-2*R])):
                input.append(input[i-R])
                target.append(torch.ones(1))
            else:
                input.append(torch.bernoulli(torch.empty(vec_len).uniform_(0, 1)))
                target.append(torch.zeros(1))
        
                
        batch_input.append(torch.stack(input, dim=0))
        batch_target.append(torch.stack(target, dim=0))
    
    input_seq = torch.stack(batch_input, dim=0)
    target_seq = torch.stack(batch_target, dim=0)
    return(input_seq,target_seq)

# %%
def generate_mix_seq(batch_size, vec_len, R, T):
    mix_input_seq = []
    mix_target_seq = []
    for r in R:
        input_seq,target_seq = generate_seq(int(batch_size/len(R)), vec_len, r, T) 
        mix_input_seq.append(input_seq)
        mix_target_seq.append(target_seq)
    
    mix_input_seq = torch.cat(mix_input_seq, dim=0)
    mix_target_seq = torch.cat(mix_target_seq, dim=0)
    shuf = np.random.permutation(len(mix_input_seq))

    return mix_input_seq[shuf],mix_target_seq[shuf]

# %%
class RNN(nn.Module):
    def __init__(self, input_size, hidden_dim, output_size):
        super(RNN, self).__init__()

        self.hidden_dim = hidden_dim
        self.rnn = nn.RNN(input_size, hidden_dim, batch_first=True)   
        self.fc = nn.Linear(hidden_dim, output_size)
        self.activation = torch.nn.Sigmoid()

    
    def forward(self, x):
        
        batch_size = x.size(0)
        hidden = self.init_hidden(batch_size)
        out, hidden = self.rnn(x, hidden)
        out = out.contiguous().view(batch_size, -1, self.hidden_dim)
        out = self.fc(out)
        out = self.activation(out)
        
        return out, hidden
    
    def init_hidden(self, batch_size):
        hidden = torch.zeros(1, batch_size, self.hidden_dim)
        return hidden

# %% [markdown]
# ## Training over the same input

# %%
training_Loss = []
valid_Loss = []
training_accuracy = []
valid_accuracy = []


vec_len = 100
R = 3
T = 500
cfd = RNN(input_size=vec_len, output_size=1, hidden_dim=100)
lr=0.0001
criterion = nn.BCELoss()
#criterion = nn.MSELoss()
optimizer = torch.optim.Adam(cfd.parameters(), lr=lr)
batch_size = 1


n_iterations = 1000
input_seq,target_seq = generate_seq(batch_size = batch_size, vec_len = vec_len, R = R, T = T)
for iterations in range(1, n_iterations + 1):
    # training
    optimizer.zero_grad() 

    output, hidden = cfd(input_seq)

    loss = criterion(output, target_seq.view(batch_size,-1,1)) 
    training_Loss.append(loss.detach().numpy())
    predicted = (output>0.5).float()
    accuracy = (predicted == target_seq).sum() / (batch_size * T)
    training_accuracy.append(accuracy.detach().numpy())

    
    loss.backward() 
    optimizer.step() 
    
    
    
    # validation
    validation_batch_size = 10
    validation_seq,validation_target_seq = generate_seq(batch_size = validation_batch_size, vec_len = vec_len, R = R, T=T)
    validation_out, hidden = cfd(validation_seq)
    validation_loss = criterion(validation_out, validation_target_seq.view(validation_batch_size,-1,1)) 
    validation_predicted = (validation_out>0.5).float()
    validation_accuracy = (validation_predicted == validation_target_seq).sum() / (validation_batch_size * T)
    valid_Loss.append(validation_loss.detach().numpy())
    valid_accuracy.append(validation_accuracy.detach().numpy())

    # print loss over epochs
    if iterations%100 == 0:
        print('Iterations: {}/{}.............'.format(iterations, n_iterations), end=' ')
        print("Loss: {:.4f}".format(validation_loss.item()), end=' | ')
        print("Accuracy: {:.4f}".format(validation_accuracy.item()))
# Out:
# Iterations: 100/1000............. Loss: 0.6383 | Accuracy: 0.6712
# Iterations: 200/1000............. Loss: 0.6553 | Accuracy: 0.6578
# Iterations: 300/1000............. Loss: 0.8678 | Accuracy: 0.5918
# Iterations: 400/1000............. Loss: 1.2162 | Accuracy: 0.5792
# Iterations: 500/1000............. Loss: 1.4157 | Accuracy: 0.5774
# Iterations: 600/1000............. Loss: 1.5561 | Accuracy: 0.5776
# Iterations: 700/1000............. Loss: 1.6526 | Accuracy: 0.5854
# Iterations: 800/1000............. Loss: 1.8223 | Accuracy: 0.5666
# Iterations: 900/1000............. Loss: 1.9142 | Accuracy: 0.5648
# Iterations: 1000/1000............. Loss: 1.9856 | Accuracy: 0.5660

# %%
plt.figure(figsize = (16, 4))
plt.subplot(1,2,1)
plt.plot(training_Loss, label = 'training loss', markersize = 3)
plt.plot(valid_Loss, label = 'validation loss', markersize = 3)
plt.title("loss")

plt.subplot(1,2,2)
plt.plot(training_accuracy, label = 'training accuracy', markersize = 3)
plt.plot(valid_accuracy, label = 'validation accuracy', markersize = 3)
plt.title("accuracy")
plt.legend()
plt.show()

# %% [markdown]
# ## Training over infinite input R3

# %%
training_Loss = []
valid_Loss = []
training_accuracy = []
valid_accuracy = []


vec_len = 100
R = 3
T = 500
cfd_R3 = RNN(input_size=vec_len, output_size=1, hidden_dim=100)
lr=0.001
criterion = nn.BCELoss()
#criterion = nn.MSELoss()
optimizer = torch.optim.Adam(cfd_R3.parameters(), lr=lr)


n_iterations = 1000
for iterations in range(1, n_iterations + 1):
    # training
    batch_size = 100
    input_seq,target_seq = generate_seq(batch_size = batch_size, vec_len = vec_len, R = R, T = T)
    optimizer.zero_grad() 

    output, hidden = cfd_R3(input_seq)

    loss = criterion(output, target_seq.view(batch_size,-1,1)) 
    training_Loss.append(loss.detach().numpy())
    predicted = (output>0.5).float()
    accuracy = (predicted == target_seq).sum() / (batch_size * T)
    training_accuracy.append(accuracy.detach().numpy())

    loss.backward() 
    optimizer.step() 
    
    # validation
    validation_batch_size = 10
    validation_seq,validation_target_seq = generate_seq(batch_size = validation_batch_size, vec_len = vec_len, R = R, T=T)
    validation_out, hidden = cfd_R3(validation_seq)
    validation_loss = criterion(validation_out, validation_target_seq.view(validation_batch_size,-1,1)) 
    validation_predicted = (validation_out>0.5).float()
    validation_accuracy = (validation_predicted == validation_target_seq).sum() / (validation_batch_size * T)
    valid_Loss.append(validation_loss.detach().numpy())
    valid_accuracy.append(validation_accuracy.detach().numpy())

    # print loss over epochs
    if iterations%100 == 0:
        print('Iterations: {}/{}.............'.format(iterations, n_iterations), end=' ')
        print("Loss: {:.4f}".format(validation_loss.item()), end=' | ')
        print("Accuracy: {:.4f}".format(validation_accuracy.item()))
# Out:
# Iterations: 100/1000............. Loss: 0.6334 | Accuracy: 0.6694
# Iterations: 200/1000............. Loss: 0.6239 | Accuracy: 0.6746
# Iterations: 300/1000............. Loss: 0.5214 | Accuracy: 0.7318
# Iterations: 400/1000............. Loss: 0.3290 | Accuracy: 0.8998
# Iterations: 500/1000............. Loss: 0.2068 | Accuracy: 0.9556
# Iterations: 600/1000............. Loss: 0.1303 | Accuracy: 0.9780
# Iterations: 700/1000............. Loss: 0.0957 | Accuracy: 0.9820
# Iterations: 800/1000............. Loss: 0.0714 | Accuracy: 0.9866
# Iterations: 900/1000............. Loss: 0.0517 | Accuracy: 0.9926
# Iterations: 1000/1000............. Loss: 0.0448 | Accuracy: 0.9910

# %%
plt.figure(figsize = (16, 4))
plt.subplot(1,2,1)
plt.plot(training_Loss, label = 'training loss', markersize = 3)
plt.plot(valid_Loss, label = 'validation loss', markersize = 3)
plt.title("loss")

plt.subplot(1,2,2)
plt.plot(training_accuracy, label = 'training accuracy', markersize = 3)
plt.plot(valid_accuracy, label = 'validation accuracy', markersize = 3)
plt.title("accuracy")
plt.legend()
plt.show()

# %% [markdown]
# ### Testing

# %%
test_Loss = []
test_accuracy = []
for test_R in range (1,10):
    test_batch_size = 1
    test_seq,test_target_seq = generate_seq(batch_size = test_batch_size, vec_len = vec_len, R = test_R, T=T)
    test_out, hidden = cfd_R3(test_seq)
    test_loss = criterion(test_out, test_target_seq.view(test_batch_size,-1,1)) 
    test_predicted = (test_out>0.5).float()
    accuracy = (test_predicted == test_target_seq).sum() / (test_batch_size * T)
    test_Loss.append(test_loss.detach().numpy())
    test_accuracy.append(accuracy.detach().numpy())

    
    
plt.figure(figsize = (16, 4))
plt.subplot(1,2,1)
r = np.arange(1,10)
plt.plot(r,test_Loss, label = 'test loss', markersize = 3)
plt.title("loss")

plt.subplot(1,2,2)
r = np.arange(1,10)
plt.plot(r,test_accuracy, label = 'test accuracy', markersize = 3)
plt.title("accuracy")
plt.legend()
plt.show()

# %% [markdown]
# gradient clipping
# reduce lr

# %% [markdown]
# ## R = 7

# %%
training_Loss = []
valid_Loss = []
training_accuracy = []
valid_accuracy = []


vec_len = 100
R = 7
T = 500
cfd_R7 = RNN(input_size=vec_len, output_size=1, hidden_dim=100)
lr=0.0001
criterion = nn.BCELoss()
#criterion = nn.MSELoss()
optimizer = torch.optim.Adam(cfd_R7.parameters(), lr=lr)


n_iterations = 10000
for iterations in range(1, n_iterations + 1):
    # training
    batch_size = 100
    input_seq,target_seq = generate_seq(batch_size = batch_size, vec_len = vec_len, R = R, T = T)
    optimizer.zero_grad() 

    output, hidden = cfd_R7(input_seq)

    loss = criterion(output, target_seq.view(batch_size,-1,1)) 
    training_Loss.append(loss.detach().numpy())
    predicted = (output>0.5).float()
    accuracy = (predicted == target_seq).sum() / (batch_size * T)
    training_accuracy.append(accuracy.detach().numpy())

    loss.backward() 
    optimizer.step() 
    
    # validation
    validation_batch_size = 10
    validation_seq,validation_target_seq = generate_seq(batch_size = validation_batch_size, vec_len = vec_len, R = R, T=T)
    validation_out, hidden = cfd_R7(validation_seq)
    validation_loss = criterion(validation_out, validation_target_seq.view(validation_batch_size,-1,1)) 
    validation_predicted = (validation_out>0.5).float()
    validation_accuracy = (validation_predicted == validation_target_seq).sum() / (validation_batch_size * T)
    valid_Loss.append(validation_loss.detach().numpy())
    valid_accuracy.append(validation_accuracy.detach().numpy())

    # print loss over epochs
    if iterations%100 == 0:
        print('Iterations: {}/{}....'.format(iterations, n_iterations), end=' ')
        print("Valid Loss: {:.4f}".format(validation_loss.item()), end=' | ')
        print("Accuracy: {:.4f}".format(validation_accuracy.item()))
# Out:
# Iterations: 100/10000.... Valid Loss: 0.6418 | Accuracy: 0.6610
# Iterations: 200/10000.... Valid Loss: 0.6307 | Accuracy: 0.6766
# Iterations: 300/10000.... Valid Loss: 0.6338 | Accuracy: 0.6726
# Iterations: 400/10000.... Valid Loss: 0.6352 | Accuracy: 0.6694
# Iterations: 500/10000.... Valid Loss: 0.6383 | Accuracy: 0.6644
# Iterations: 600/10000.... Valid Loss: 0.6309 | Accuracy: 0.6750
# Iterations: 700/10000.... Valid Loss: 0.6387 | Accuracy: 0.6636
# Iterations: 800/10000.... Valid Loss: 0.6349 | Accuracy: 0.6672
# Iterations: 900/10000.... Valid Loss: 0.6327 | Accuracy: 0.6684
# Iterations: 1000/10000.... Valid Loss: 0.6359 | Accuracy: 0.6634
# Iterations: 1100/10000.... Valid Loss: 0.6287 | Accuracy: 0.6728
# Iterations: 1200/10000.... Valid Loss: 0.6349 | Accuracy: 0.6636
# Iterations: 1300/10000.... Valid Loss: 0.6289 | Accuracy: 0.6720
# Iterations: 1400/10000.... Valid Loss: 0.6298 | Accuracy: 0.6702
# Iterations: 1500/10000.... Valid Loss: 0.6282 | Accuracy: 0.6730
# Iterations: 1600/10000.... Valid Loss: 0.6274 | Accuracy: 0.6728
# Iterations: 1700/10000.... Valid Loss: 0.6291 | Accuracy: 0.6702
# Iterations: 1800/10000.... Valid Loss: 0.6292 | Accuracy: 0.6700
# Iterations: 1900/10000.... Valid Loss: 0.6292 | Accuracy: 0.6698
# Iterations: 2000/10000.... Valid Loss: 0.6327 | Accuracy: 0.6650
# Iterations: 2100/10000.... Valid Loss: 0.6309 | Accuracy: 0.6670
# Iterations: 2200/10000.... Valid Loss: 0.6298 | Accuracy: 0.6668
# Iterations: 2300/10000.... Valid Loss: 0.6324 | Accuracy: 0.6638
# Iterations: 9900/10000.... Valid Loss: 0.3410 | Accuracy: 0.8862
# Iterations: 10000/10000.... Valid Loss: 0.3427 | Accuracy: 0.8826

# %%
n_iterations = 15000
for iterations in range(10001, n_iterations + 1):
    # training
    batch_size = 100
    input_seq,target_seq = generate_seq(batch_size = batch_size, vec_len = vec_len, R = R, T = T)
    optimizer.zero_grad() 

    output, hidden = cfd_R7(input_seq)

    loss = criterion(output, target_seq.view(batch_size,-1,1)) 
    training_Loss.append(loss.detach().numpy())
    predicted = (output>0.5).float()
    accuracy = (predicted == target_seq).sum() / (batch_size * T)
    training_accuracy.append(accuracy.detach().numpy())

    loss.backward() 
    optimizer.step() 
    
    # validation
    validation_batch_size = 10
    validation_seq,validation_target_seq = generate_seq(batch_size = validation_batch_size, vec_len = vec_len, R = R, T=T)
    validation_out, hidden = cfd_R7(validation_seq)
    validation_loss = criterion(validation_out, validation_target_seq.view(validation_batch_size,-1,1)) 
    validation_predicted = (validation_out>0.5).float()
    validation_accuracy = (validation_predicted == validation_target_seq).sum() / (validation_batch_size * T)
    valid_Loss.append(validation_loss.detach().numpy())
    valid_accuracy.append(validation_accuracy.detach().numpy())

    # print loss over epochs
    if iterations%100 == 0:
        print('Iterations: {}/{}....'.format(iterations, n_iterations), end=' ')
        print("Valid Loss: {:.4f}".format(validation_loss.item()), end=' | ')
        print("Accuracy: {:.4f}".format(validation_accuracy.item()))
# Out:
# Iterations: 10100/15000.... Valid Loss: 0.3374 | Accuracy: 0.8820
# Iterations: 10200/15000.... Valid Loss: 0.3330 | Accuracy: 0.8868
# Iterations: 10300/15000.... Valid Loss: 0.3263 | Accuracy: 0.8800
# Iterations: 10400/15000.... Valid Loss: 0.3264 | Accuracy: 0.8816
# Iterations: 10500/15000.... Valid Loss: 0.3223 | Accuracy: 0.8882
# Iterations: 10600/15000.... Valid Loss: 0.3247 | Accuracy: 0.8806
# Iterations: 10700/15000.... Valid Loss: 0.3185 | Accuracy: 0.8838
# Iterations: 10800/15000.... Valid Loss: 0.3069 | Accuracy: 0.8896
# Iterations: 10900/15000.... Valid Loss: 0.3167 | Accuracy: 0.8842
# Iterations: 11000/15000.... Valid Loss: 0.3166 | Accuracy: 0.8898
# Iterations: 11100/15000.... Valid Loss: 0.3105 | Accuracy: 0.8844
# Iterations: 11200/15000.... Valid Loss: 0.2979 | Accuracy: 0.8886
# Iterations: 11300/15000.... Valid Loss: 0.3032 | Accuracy: 0.8870
# Iterations: 11400/15000.... Valid Loss: 0.3042 | Accuracy: 0.8816
# Iterations: 11500/15000.... Valid Loss: 0.3011 | Accuracy: 0.8922
# Iterations: 11600/15000.... Valid Loss: 0.2962 | Accuracy: 0.8848
# Iterations: 11700/15000.... Valid Loss: 0.2916 | Accuracy: 0.8934
# Iterations: 11800/15000.... Valid Loss: 0.2863 | Accuracy: 0.8974
# Iterations: 11900/15000.... Valid Loss: 0.2867 | Accuracy: 0.8866
# Iterations: 12000/15000.... Valid Loss: 0.2746 | Accuracy: 0.9008
# Iterations: 12100/15000.... Valid Loss: 0.2842 | Accuracy: 0.8934
# Iterations: 12200/15000.... Valid Loss: 0.2814 | Accuracy: 0.8906
# Iterations: 12300/15000.... Valid Loss: 0.2847 | Accuracy: 0.8934
# Iterations: 12400/15000.... Valid Loss: 0.2712 | Accuracy: 0.9022
# Iterations: 12500/15000.... Valid Loss: 0.2670 | Accuracy: 0.9006
# Iterations: 12600/15000.... Valid Loss: 0.2728 | Accuracy: 0.8988
# Iterations: 12700/15000.... Valid Loss: 0.2759 | Accuracy: 0.8958
# Iterations: 12800/15000.... Valid Loss: 0.2676 | Accuracy: 0.9022
# Iterations: 12900/15000.... Valid Loss: 0.2721 | Accuracy: 0.8978
# Iterations: 13000/15000.... Valid Loss: 0.2692 | Accuracy: 0.8972
# Iterations: 13100/15000.... Valid Loss: 0.2621 | Accuracy: 0.9066
# Iterations: 13200/15000.... Valid Loss: 0.2702 | Accuracy: 0.8906
# Iterations: 13300/15000.... Valid Loss: 0.2622 | Accuracy: 0.9028
# Iterations: 13400/15000.... Valid Loss: 0.2623 | Accuracy: 0.8976
# Iterations: 13500/15000.... Valid Loss: 0.2589 | Accuracy: 0.9034
# Iterations: 13600/15000.... Valid Loss: 0.2529 | Accuracy: 0.9090
# Iterations: 13700/15000.... Valid Loss: 0.2515 | Accuracy: 0.9062
# Iterations: 13800/15000.... Valid Loss: 0.2500 | Accuracy: 0.9074
# Iterations: 13900/15000.... Valid Loss: 0.2487 | Accuracy: 0.9022
# Iterations: 14000/15000.... Valid Loss: 0.2419 | Accuracy: 0.9116
# Iterations: 14100/15000.... Valid Loss: 0.2510 | Accuracy: 0.9034
# Iterations: 14200/15000.... Valid Loss: 0.2554 | Accuracy: 0.9010
# Iterations: 14300/15000.... Valid Loss: 0.2549 | Accuracy: 0.9014
# Iterations: 14400/15000.... Valid Loss: 0.2485 | Accuracy: 0.9068
# Iterations: 14500/15000.... Valid Loss: 0.2480 | Accuracy: 0.9056
# Iterations: 14600/15000.... Valid Loss: 0.2492 | Accuracy: 0.9020
# Iterations: 14700/15000.... Valid Loss: 0.2491 | Accuracy: 0.9054
# Iterations: 14800/15000.... Valid Loss: 0.2387 | Accuracy: 0.9104
# Iterations: 14900/15000.... Valid Loss: 0.2395 | Accuracy: 0.9060
# Iterations: 15000/15000.... Valid Loss: 0.2373 | Accuracy: 0.9112

# %%
n_iterations = 20000
for iterations in range(15001, n_iterations + 1):
    # training
    batch_size = 100
    input_seq,target_seq = generate_seq(batch_size = batch_size, vec_len = vec_len, R = R, T = T)
    optimizer.zero_grad() 

    output, hidden = cfd_R7(input_seq)

    loss = criterion(output, target_seq.view(batch_size,-1,1)) 
    training_Loss.append(loss.detach().numpy())
    predicted = (output>0.5).float()
    accuracy = (predicted == target_seq).sum() / (batch_size * T)
    training_accuracy.append(accuracy.detach().numpy())

    loss.backward() 
    optimizer.step() 
    
    # validation
    validation_batch_size = 10
    validation_seq,validation_target_seq = generate_seq(batch_size = validation_batch_size, vec_len = vec_len, R = R, T=T)
    validation_out, hidden = cfd_R7(validation_seq)
    validation_loss = criterion(validation_out, validation_target_seq.view(validation_batch_size,-1,1)) 
    validation_predicted = (validation_out>0.5).float()
    validation_accuracy = (validation_predicted == validation_target_seq).sum() / (validation_batch_size * T)
    valid_Loss.append(validation_loss.detach().numpy())
    valid_accuracy.append(validation_accuracy.detach().numpy())

    # print loss over epochs
    if iterations%100 == 0:
        print('Iterations: {}/{}....'.format(iterations, n_iterations), end=' ')
        print("Valid Loss: {:.4f}".format(validation_loss.item()), end=' | ')
        print("Accuracy: {:.4f}".format(validation_accuracy.item()))
# Out:
# Iterations: 15100/20000.... Valid Loss: 0.2365 | Accuracy: 0.9082
# Iterations: 15200/20000.... Valid Loss: 0.2378 | Accuracy: 0.9092
# Iterations: 15300/20000.... Valid Loss: 0.2227 | Accuracy: 0.9170
# Iterations: 15400/20000.... Valid Loss: 0.2299 | Accuracy: 0.9156
# Iterations: 15500/20000.... Valid Loss: 0.2390 | Accuracy: 0.9048
# Iterations: 15600/20000.... Valid Loss: 0.2342 | Accuracy: 0.9086
# Iterations: 15700/20000.... Valid Loss: 0.2379 | Accuracy: 0.9074
# Iterations: 15800/20000.... Valid Loss: 0.2319 | Accuracy: 0.9092
# Iterations: 15900/20000.... Valid Loss: 0.2291 | Accuracy: 0.9126
# Iterations: 16000/20000.... Valid Loss: 0.2250 | Accuracy: 0.9158
# Iterations: 16100/20000.... Valid Loss: 0.2287 | Accuracy: 0.9134
# Iterations: 16200/20000.... Valid Loss: 0.2223 | Accuracy: 0.9130
# Iterations: 16300/20000.... Valid Loss: 0.2242 | Accuracy: 0.9120
# Iterations: 16400/20000.... Valid Loss: 0.2248 | Accuracy: 0.9110
# Iterations: 16500/20000.... Valid Loss: 0.2248 | Accuracy: 0.9124
# Iterations: 16600/20000.... Valid Loss: 0.2231 | Accuracy: 0.9144
# Iterations: 16700/20000.... Valid Loss: 0.2190 | Accuracy: 0.9148
# Iterations: 16800/20000.... Valid Loss: 0.2096 | Accuracy: 0.9218
# Iterations: 16900/20000.... Valid Loss: 0.2173 | Accuracy: 0.9180
# Iterations: 17000/20000.... Valid Loss: 0.2203 | Accuracy: 0.9122
# Iterations: 17100/20000.... Valid Loss: 0.2153 | Accuracy: 0.9190
# Iterations: 17200/20000.... Valid Loss: 0.2174 | Accuracy: 0.9140
# Iterations: 17300/20000.... Valid Loss: 0.2206 | Accuracy: 0.9116
# Iterations: 17400/20000.... Valid Loss: 0.2171 | Accuracy: 0.9154
# Iterations: 17500/20000.... Valid Loss: 0.2125 | Accuracy: 0.9190
# Iterations: 17600/20000.... Valid Loss: 0.2121 | Accuracy: 0.9192
# Iterations: 17700/20000.... Valid Loss: 0.2155 | Accuracy: 0.9108
# Iterations: 17800/20000.... Valid Loss: 0.2147 | Accuracy: 0.9158
# Iterations: 17900/20000.... Valid Loss: 0.2087 | Accuracy: 0.9216
# Iterations: 18000/20000.... Valid Loss: 0.2095 | Accuracy: 0.9216
# Iterations: 18100/20000.... Valid Loss: 0.2057 | Accuracy: 0.9232
# Iterations: 18200/20000.... Valid Loss: 0.2077 | Accuracy: 0.9194
# Iterations: 18300/20000.... Valid Loss: 0.2103 | Accuracy: 0.9214
# Iterations: 18400/20000.... Valid Loss: 0.2099 | Accuracy: 0.9186
# Iterations: 18500/20000.... Valid Loss: 0.2129 | Accuracy: 0.9142
# Iterations: 18600/20000.... Valid Loss: 0.2097 | Accuracy: 0.9170
# Iterations: 18700/20000.... Valid Loss: 0.2010 | Accuracy: 0.9216
# Iterations: 18800/20000.... Valid Loss: 0.2052 | Accuracy: 0.9192
# Iterations: 18900/20000.... Valid Loss: 0.1997 | Accuracy: 0.9260
# Iterations: 19000/20000.... Valid Loss: 0.2077 | Accuracy: 0.9170
# Iterations: 19100/20000.... Valid Loss: 0.1960 | Accuracy: 0.9288
# Iterations: 19200/20000.... Valid Loss: 0.1974 | Accuracy: 0.9256
# Iterations: 19300/20000.... Valid Loss: 0.1935 | Accuracy: 0.9276
# Iterations: 19400/20000.... Valid Loss: 0.2009 | Accuracy: 0.9220
# Iterations: 19500/20000.... Valid Loss: 0.1967 | Accuracy: 0.9236
# Iterations: 19600/20000.... Valid Loss: 0.2063 | Accuracy: 0.9210
# Iterations: 19700/20000.... Valid Loss: 0.1927 | Accuracy: 0.9256
# Iterations: 19800/20000.... Valid Loss: 0.1944 | Accuracy: 0.9262
# Iterations: 19900/20000.... Valid Loss: 0.1951 | Accuracy: 0.9252
# Iterations: 20000/20000.... Valid Loss: 0.1980 | Accuracy: 0.9218

# %%
plt.figure(figsize = (16, 4))
plt.subplot(1,2,1)
plt.plot(training_Loss, label = 'training loss', markersize = 3)
plt.plot(valid_Loss, label = 'validation loss', markersize = 3)
plt.title("loss")

plt.subplot(1,2,2)
plt.plot(training_accuracy, label = 'training accuracy', markersize = 3)
plt.plot(valid_accuracy, label = 'validation accuracy', markersize = 3)
plt.title("accuracy")
plt.legend()
plt.show()

# %%
test_Loss = []
test_accuracy = []
for test_R in range (1,10):
    test_batch_size = 1
    test_seq,test_target_seq = generate_seq(batch_size = test_batch_size, vec_len = vec_len, R = test_R, T=T)
    test_out, hidden = cfd_R7(test_seq)
    test_loss = criterion(test_out, test_target_seq.view(test_batch_size,-1,1)) 
    test_predicted = (test_out>0.5).float()
    accuracy = (test_predicted == test_target_seq).sum() / (test_batch_size * T)
    test_Loss.append(test_loss.detach().numpy())
    test_accuracy.append(accuracy.detach().numpy())

    
    
plt.figure(figsize = (16, 4))
plt.subplot(1,2,1)
r = np.arange(1,10)
plt.plot(r,test_Loss, label = 'test loss', markersize = 3)
plt.title("loss")

plt.subplot(1,2,2)
r = np.arange(1,10)
plt.plot(r,test_accuracy, label = 'test accuracy', markersize = 3)
plt.title("accuracy")
plt.legend()
plt.show()

# %% [markdown]
# ## Mix training with R = [3,7]

# %%
training_Loss = []
valid_Loss = []
training_accuracy = []
valid_accuracy = []


vec_len = 100
R = [3,7]
T = 500
cfd_R37 = RNN(input_size=vec_len, output_size=1, hidden_dim=100)
lr=0.0001
criterion = nn.BCELoss()
#criterion = nn.MSELoss()
optimizer = torch.optim.Adam(cfd_R37.parameters(), lr=lr)


n_iterations = 10000
for iterations in range(1, n_iterations + 1):
    # training
    batch_size = 100
    input_seq,target_seq = generate_mix_seq(batch_size = batch_size, vec_len = vec_len, R = R, T = T)
    optimizer.zero_grad() 

    output, hidden = cfd_R37(input_seq)

    loss = criterion(output, target_seq.view(batch_size,-1,1)) 
    training_Loss.append(loss.detach().numpy())
    predicted = (output>0.5).float()
    accuracy = (predicted == target_seq).sum() / (batch_size * T)
    training_accuracy.append(accuracy.detach().numpy())

    loss.backward() 
    optimizer.step() 
      
    # validation
    validation_batch_size = 10
    validation_seq,validation_target_seq = generate_mix_seq(batch_size = validation_batch_size, vec_len = vec_len, R = R, T=T)
    validation_out, hidden = cfd_R37(validation_seq)
    validation_loss = criterion(validation_out, validation_target_seq.view(validation_batch_size,-1,1)) 
    validation_predicted = (validation_out>0.5).float()
    validation_accuracy = (validation_predicted == validation_target_seq).sum() / (validation_batch_size * T)
    valid_Loss.append(validation_loss.detach().numpy())
    valid_accuracy.append(validation_accuracy.detach().numpy())

    # print loss over epochs
    if iterations%100 == 0:
        print('Iterations: {}/{}....'.format(iterations, n_iterations), end=' ')
        print("Valid Loss: {:.4f}".format(validation_loss.item()), end=' | ')
        print("Accuracy: {:.4f}".format(validation_accuracy.item()))
# Out:
# Iterations: 100/10000.... Valid Loss: 0.6345 | Accuracy: 0.6740
# Iterations: 200/10000.... Valid Loss: 0.6361 | Accuracy: 0.6690
# Iterations: 300/10000.... Valid Loss: 0.6341 | Accuracy: 0.6714
# Iterations: 400/10000.... Valid Loss: 0.6326 | Accuracy: 0.6734
# Iterations: 500/10000.... Valid Loss: 0.6338 | Accuracy: 0.6714
# Iterations: 600/10000.... Valid Loss: 0.6328 | Accuracy: 0.6720
# Iterations: 700/10000.... Valid Loss: 0.6304 | Accuracy: 0.6744
# Iterations: 800/10000.... Valid Loss: 0.6374 | Accuracy: 0.6646
# Iterations: 900/10000.... Valid Loss: 0.6331 | Accuracy: 0.6700
# Iterations: 1000/10000.... Valid Loss: 0.6305 | Accuracy: 0.6730
# Iterations: 1100/10000.... Valid Loss: 0.6252 | Accuracy: 0.6780
# Iterations: 1200/10000.... Valid Loss: 0.6293 | Accuracy: 0.6682
# Iterations: 1300/10000.... Valid Loss: 0.6250 | Accuracy: 0.6712
# Iterations: 1400/10000.... Valid Loss: 0.6263 | Accuracy: 0.6626
# Iterations: 1500/10000.... Valid Loss: 0.6183 | Accuracy: 0.6672
# Iterations: 1600/10000.... Valid Loss: 0.6087 | Accuracy: 0.6704
# Iterations: 1700/10000.... Valid Loss: 0.5995 | Accuracy: 0.6810
# Iterations: 1800/10000.... Valid Loss: 0.5943 | Accuracy: 0.6848
# Iterations: 9400/10000.... Valid Loss: 0.2453 | Accuracy: 0.9106
# Iterations: 9500/10000.... Valid Loss: 0.2317 | Accuracy: 0.9102
# Iterations: 9600/10000.... Valid Loss: 0.2164 | Accuracy: 0.9222
# Iterations: 9700/10000.... Valid Loss: 0.2235 | Accuracy: 0.9164
# Iterations: 9800/10000.... Valid Loss: 0.2232 | Accuracy: 0.9156
# Iterations: 9900/10000.... Valid Loss: 0.2247 | Accuracy: 0.9134
# Iterations: 10000/10000.... Valid Loss: 0.2162 | Accuracy: 0.9198

# %%
plt.figure(figsize = (16, 4))
plt.subplot(1,2,1)
plt.plot(training_Loss, label = 'training loss', markersize = 3)
plt.plot(valid_Loss, label = 'validation loss', markersize = 3)
plt.title("loss")

plt.subplot(1,2,2)
plt.plot(training_accuracy, label = 'training accuracy', markersize = 3)
plt.plot(valid_accuracy, label = 'validation accuracy', markersize = 3)
plt.title("accuracy")
plt.legend()
plt.show()

# %%
test_Loss = []
test_accuracy = []
for test_R in range (1,10):
    test_batch_size = 1
    test_seq,test_target_seq = generate_seq(batch_size = test_batch_size, vec_len = vec_len, R = test_R, T=T)
    test_out, hidden = cfd_R37(test_seq)
    test_loss = criterion(test_out, test_target_seq.view(test_batch_size,-1,1)) 
    test_predicted = (test_out>0.5).float()
    accuracy = (test_predicted == test_target_seq).sum() / (test_batch_size * T)
    test_Loss.append(test_loss.detach().numpy())
    test_accuracy.append(accuracy.detach().numpy())

    
    
plt.figure(figsize = (16, 4))
plt.subplot(1,2,1)
r = np.arange(1,10)
plt.plot(r,test_Loss, label = 'test loss', markersize = 3)
plt.title("loss")

plt.subplot(1,2,2)
r = np.arange(1,10)
plt.plot(r,test_accuracy, label = 'test accuracy', markersize = 3)
plt.title("accuracy")
plt.legend()
plt.show()

# %%
n_iterations = 20000
for iterations in range(10001, n_iterations + 1):
    # training
    batch_size = 100
    input_seq,target_seq = generate_mix_seq(batch_size = batch_size, vec_len = vec_len, R = R, T = T)
    optimizer.zero_grad() 

    output, hidden = cfd_R37(input_seq)

    loss = criterion(output, target_seq.view(batch_size,-1,1)) 
    training_Loss.append(loss.detach().numpy())
    predicted = (output>0.5).float()
    accuracy = (predicted == target_seq).sum() / (batch_size * T)
    training_accuracy.append(accuracy.detach().numpy())

    loss.backward() 
    optimizer.step() 
      
    # validation
    validation_batch_size = 10
    validation_seq,validation_target_seq = generate_mix_seq(batch_size = validation_batch_size, vec_len = vec_len, R = R, T=T)
    validation_out, hidden = cfd_R37(validation_seq)
    validation_loss = criterion(validation_out, validation_target_seq.view(validation_batch_size,-1,1)) 
    validation_predicted = (validation_out>0.5).float()
    validation_accuracy = (validation_predicted == validation_target_seq).sum() / (validation_batch_size * T)
    valid_Loss.append(validation_loss.detach().numpy())
    valid_accuracy.append(validation_accuracy.detach().numpy())

    # print loss over epochs
    if iterations%100 == 0:
        print('Iterations: {}/{}....'.format(iterations, n_iterations), end=' ')
# Iterations: 17400/20000.... Valid Loss: 0.1630 | Accuracy: 0.9388
# Iterations: 17500/20000.... Valid Loss: 0.1391 | Accuracy: 0.9516
# Iterations: 17600/20000.... Valid Loss: 0.1496 | Accuracy: 0.9460
# Iterations: 17700/20000.... Valid Loss: 0.8474 | Accuracy: 0.7604
# Iterations: 17800/20000.... Valid Loss: 0.5669 | Accuracy: 0.7534
# Iterations: 17900/20000.... Valid Loss: 0.5453 | Accuracy: 0.7678
# Iterations: 18000/20000.... Valid Loss: 0.5341 | Accuracy: 0.7646
# Iterations: 18100/20000.... Valid Loss: 0.5108 | Accuracy: 0.7738
# Iterations: 18200/20000.... Valid Loss: 0.5107 | Accuracy: 0.7738
# Iterations: 18300/20000.... Valid Loss: 0.4950 | Accuracy: 0.7778
# Iterations: 18400/20000.... Valid Loss: 0.5006 | Accuracy: 0.7686
# Iterations: 18500/20000.... Valid Loss: 0.4815 | Accuracy: 0.7800
# Iterations: 18600/20000.... Valid Loss: 0.4852 | Accuracy: 0.7752
# Iterations: 18700/20000.... Valid Loss: 0.4423 | Accuracy: 0.7950
# Iterations: 18800/20000.... Valid Loss: 0.4326 | Accuracy: 0.7896
# Iterations: 18900/20000.... Valid Loss: 0.4164 | Accuracy: 0.7856
# Iterations: 19000/20000.... Valid Loss: 0.4010 | Accuracy: 0.7988
# Iterations: 19100/20000.... Valid Loss: 0.3770 | Accuracy: 0.8166
# Iterations: 19200/20000.... Valid Loss: 0.3788 | Accuracy: 0.8094
# Iterations: 19300/20000.... Valid Loss: 0.4246 | Accuracy: 0.7930
# Iterations: 19400/20000.... Valid Loss: 0.5019 | Accuracy: 0.7562
# Iterations: 19500/20000.... Valid Loss: 0.3818 | Accuracy: 0.8092
# Iterations: 19600/20000.... Valid Loss: 0.3697 | Accuracy: 0.8118
# Iterations: 19700/20000.... Valid Loss: 0.3774 | Accuracy: 0.8142
# Iterations: 19800/20000.... Valid Loss: 0.3621 | Accuracy: 0.8200
# Iterations: 19900/20000.... Valid Loss: 0.3555 | Accuracy: 0.8290
# Iterations: 20000/20000.... Valid Loss: 0.3437 | Accuracy: 0.8362

# %%
test_Loss = []
test_accuracy = []
for test_R in range (1,10):
    test_batch_size = 1
    test_seq,test_target_seq = generate_seq(batch_size = test_batch_size, vec_len = vec_len, R = test_R, T=T)
    test_out, hidden = cfd_R37(test_seq)
    test_loss = criterion(test_out, test_target_seq.view(test_batch_size,-1,1)) 
    test_predicted = (test_out>0.5).float()
    accuracy = (test_predicted == test_target_seq).sum() / (test_batch_size * T)
    test_Loss.append(test_loss.detach().numpy())
    test_accuracy.append(accuracy.detach().numpy())

    
    
plt.figure(figsize = (16, 4))
plt.subplot(1,2,1)
r = np.arange(1,10)
plt.plot(r,test_Loss, label = 'test loss', markersize = 3)
plt.title("loss")

plt.subplot(1,2,2)
r = np.arange(1,10)
plt.plot(r,test_accuracy, label = 'test accuracy', markersize = 3)
plt.title("accuracy")
plt.legend()
plt.show()
